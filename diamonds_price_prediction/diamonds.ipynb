# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
plt.hist(df['carat'], bins=20, edgecolor='black')
plt.show()

# %%
sns.boxplot(data=df, x='carat')
# Out:
# <Axes: xlabel='carat'>

# %%
plt.hist(df['depth'], bins=20, edgecolor='black')
plt.show()

# %%
sns.boxplot(data=df, x='depth')
# Out:
# <Axes: xlabel='depth'>

# %%
plt.hist(df['table'], bins=20, edgecolor='black')
plt.show()

# %%
sns.boxplot(data=df, x='table')
# Out:
# <Axes: xlabel='table'>

# %%
plt.hist(df['price'], bins=20, edgecolor='black')
plt.show()

# %%
sns.boxplot(data=df, x='price')
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.hist(df['x'], bins=20, edgecolor='black')
plt.title('x')

plt.subplot(1, 3, 2)  
plt.hist(df['y'], bins=20, edgecolor='black')
plt.title('y')

plt.subplot(1, 3, 3)  
plt.hist(df['z'], bins=20, edgecolor="black")
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
sns.boxplot(data=df, x='x')
plt.show()

# %%
sns.boxplot(data=df, x='y')
# Out:
# <Axes: xlabel='y'>

# %%
sns.boxplot(data=df, x='z')
# Out:
# <Axes: xlabel='z'>

# %%
#qualitatives
clarity_counts = df['clarity'].value_counts()
clarity_counts.plot(kind='bar', edgecolor='black')
plt.show()

# %%
color_counts = df['color'].value_counts()
color_counts.plot(kind='bar', edgecolor='black')
plt.show()

# %%
cut_counts = df['cut'].value_counts()
cut_counts.plot(kind='bar', edgecolor='black')
plt.show()

# %% [markdown]
# Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_col = ['cut','clarity','color']

#Label Encoder
le = LabelEncoder()
for col in cat_col:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    Unnamed: 0  carat  cut  color  clarity  depth  table  price     x     y  \
# 0           1   0.23    2      1        3   61.5   55.0    326  3.95  3.98
# 1           2   0.21    3      1        2   59.8   61.0    326  3.89  3.84
# 2           3   0.23    1      1        4   56.9   65.0    327  4.05  4.07
# 3           4   0.29    3      5        5   62.4   58.0    334  4.20  4.23
# 4           5   0.31    1      6        3   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
#heatmap 
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
#outliers detection
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR = q3 - q1

# Print Outliers
((df < (q1 - 1.5 * IQR)) | (df > (q3 + 1.5 * IQR))).sum()
# Out:
# carat      1889
# cut        1610
# color         0
# clarity       0
# depth      2545
# table       605
# price      3540
# x            32
# y            29
# z            49
# dtype: int64

# %%
#remove outliers 
df = df[~((df < (q1 - 1.5 * IQR)) | (df > (q3 + 1.5 * IQR))).any(axis=1)]
((df < (q1 - 1.5 * IQR)) | (df > (q3 + 1.5 * IQR))).sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
sns.scatterplot(data=df, x="x", y="carat")
plt.show()

# %%
sns.scatterplot(data=df, x="x", y="y")
plt.show()

# %%
sns.scatterplot(data=df, x="x", y="z")
plt.show()

# %%
sns.scatterplot(data=df, x="price", y="carat")
plt.show()

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
X = df.drop("price", axis = "columns")
Y = df["price"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (37755, 9) (9439, 9) (37755,) (9439,)

# %%
#scaling data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(X_train_scaled, X_test_scaled)
# Out:
# [[-0.77367378  0.3851077   0.27211632 ... -0.70589186 -0.78718972
#   -0.8334976 ]
#  [ 0.00706656  0.3851077  -0.91347617 ...  0.20068956  0.13489151
#    0.20515014]
#  [-0.39676465 -0.69454933 -0.91347617 ... -0.2576943  -0.23394099
#   -0.28944402]
#  ...
#  [-0.34292049 -0.69454933 -0.32067992 ... -0.15583122 -0.14173286
#   -0.22349813]
#  [-0.12754385 -0.69454933  0.27211632 ...  0.06826755  0.03243804
#    0.02379895]
#  [ 1.43393683  0.3851077  -0.32067992 ...  1.34155606  1.38482383
#    1.34271671]] [[ 1.38009267  0.3851077   0.86491257 ...  1.2533197   1.2772592
#    1.69011023]
#  [ 1.08394978  1.46476473  0.27211632 ...  1.13054433  1.24555619
#    1.39983056]
#  [ 0.0878328   0.3851077  -0.32067992 ...  0.26088547  0.25219497
#    0.61436793]
#  ...
#  [ 1.21856019  0.3851077   0.27211632 ...  1.22262586  1.16101481
#    1.53643276]
#  [ 2.18775509  0.3851077  -1.50627241 ...  1.96950935  1.97472559
#    2.28774484]
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
forest_regressor = RandomForestRegressor()

# %%
forest = RandomForestRegressor(n_estimators=100)

forest.fit(X_train_scaled, Y_train)
score=forest.score(X_test_scaled, Y_test)

print("R^2 for a scaled test set:",score)
# Out:
# R^2 for a scaled test set: 0.9778631612757993
